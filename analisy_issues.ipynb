# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('issues/android-slideshow.csv')
df
# Out:
#                           repository   state  \
# 0    ScreamingHawk/android-slideshow    open
# 1    ScreamingHawk/android-slideshow    open
# 2    ScreamingHawk/android-slideshow  closed
# 3    ScreamingHawk/android-slideshow  closed
# 4    ScreamingHawk/android-slideshow  closed
# 5    ScreamingHawk/android-slideshow    open
# 6    ScreamingHawk/android-slideshow  closed
# 7    ScreamingHawk/android-slideshow  closed
# 8    ScreamingHawk/android-slideshow    open
# 9    ScreamingHawk/android-slideshow  closed
# 10   ScreamingHawk/android-slideshow  closed
# 11   ScreamingHawk/android-slideshow  closed
# 12   ScreamingHawk/android-slideshow  closed
# 13   ScreamingHawk/android-slideshow  closed
# 14   ScreamingHawk/android-slideshow  closed
# 15   ScreamingHawk/android-slideshow  closed
# 16   ScreamingHawk/android-slideshow    open
# 17   ScreamingHawk/android-slideshow  closed
# 18   ScreamingHawk/android-slideshow    open
# 19   ScreamingHawk/android-slideshow  closed
# ...

# %%
df['state'].value_counts()
# Out:
# closed    108
# open       22
# Name: state, dtype: int64
